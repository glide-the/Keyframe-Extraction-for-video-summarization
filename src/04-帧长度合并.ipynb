# %%
import cv2


def read_fps(video_path:str):
    # 打开视频文件
    video_capture = cv2.VideoCapture(video_path)
    
    # 获取视频的帧速率
    fps = int(video_capture.get(cv2.CAP_PROP_FPS))
     
    # 释放视频捕获对象
    video_capture.release()
    
    # 关闭视频文件
    cv2.destroyAllWindows()
    return fps

# %%
import datetime

def is_frame_in_time_interval(frame_number: int, start_time:str, end_time:str, fps:int):
    # 将开始时间和结束时间解析为时间对象
    start_time_obj = datetime.datetime.strptime(start_time, "%H:%M:%S,%f")
    end_time_obj = datetime.datetime.strptime(end_time, "%H:%M:%S,%f")

    # 计算时间区间的秒数
    start_seconds = (start_time_obj.hour * 3600 + start_time_obj.minute * 60 + start_time_obj.second +
                     start_time_obj.microsecond / 1000000)
    end_seconds = (end_time_obj.hour * 3600 + end_time_obj.minute * 60 + end_time_obj.second +
                   end_time_obj.microsecond / 1000000)
    
    # 计算帧在时间区间内的时间
    frame_time = frame_number / fps
    # 检查帧时间是否在时间区间内
    return start_seconds <= frame_time <= end_seconds

# %%
import pandas as pd
from typing import List

def add_scene_column(input_csv_file, output_csv_file, fps, keyframes: List[int] = []):
    # 读取CSV文件
    df = pd.read_csv(input_csv_file)

    # 初始化分镜列
    df['分镜'] = 0
    pre_k_index = 0
    
    # 遍历每一行
    for index, row in df.iterrows():
        start_time = row['开始时间']
        end_time = row['结束时间']
        _flag = False
        for k_index, frame_number in enumerate(keyframes):
            print(f"frame_number:{frame_number}")
            is_frame = is_frame_in_time_interval(frame_number=frame_number,
                                                 start_time=start_time, 
                                                 end_time=end_time,
                                                 fps=fps)
            if is_frame:
                # 判断是否应增加分镜值
                df.at[index, '分镜'] = k_index
                pre_k_index = k_index
                _flag=True

        # 如果不存在分镜片段，获取上次的序号
        if not _flag:
            df.at[index, '分镜'] = pre_k_index
                

    # 保存带有新列的CSV文件
    df.to_csv(output_csv_file, index=False)

 
'''
获取输入文件夹内的所有load_keyframe文件，并返回文件名列表
'''
def load_keyframe(file_dir):
    L = []
    for root, dirs, files in os.walk(file_dir):
        for file in files:
            if os.path.splitext(file)[1] == '.jpg': 
                # 使用os.path.basename获取文件名（包括扩展名）
                file_name_with_extension = os.path.basename(file)
                # 使用os.path.splitext获取文件名和扩展名的分隔结果
                file_name, file_extension = os.path.splitext(file_name_with_extension)
                L.append(int(file_name))
        return L 


def csv_keyframe_merge(root_path,video_source):
    save_path = f'{root_path}/{video_source}/'
    video_path=f'{save_path}/{video_source}.mp4'
    csv_path=f'{save_path}/str/{video_source}.csv'
    output_csv_path=f'{save_path}/str/{video_source}_keyframe.csv'

    print("save_path{}".format(save_path))
    print("video_path{}".format(video_path))
    print("csv_path{}".format(csv_path))
    print("output_csv_path{}".format(output_csv_path))
    
    keyframe_path=f'{save_path}/keyframe'
    keyframes=load_keyframe(keyframe_path) 
    print("获取keyframes，成功{}".format(keyframes))
    fps = read_fps(video_path)
    add_scene_column(input_csv_file=csv_path, output_csv_file=output_csv_path, fps=fps, keyframes=keyframes)

# %%
import os

root_path = '/media/checkpoint/speech_data/抖音作品/'
for root, dirs, files in os.walk(root_path):
    # 如果你只想获取下一层的子目录，可以在这里筛选
    if root == root_path:
        # root_dir 下的直接子目录就是 dirs 中的项
        for dir in dirs:
            
            csv_keyframe_merge(root_path,dir)
# Out:
# save_path/media/checkpoint/speech_data/抖音作品//ieAeWyXU/
# video_path/media/checkpoint/speech_data/抖音作品//ieAeWyXU//ieAeWyXU.mp4
# csv_path/media/checkpoint/speech_data/抖音作品//ieAeWyXU//str/ieAeWyXU.csv
# output_csv_path/media/checkpoint/speech_data/抖音作品//ieAeWyXU//str/ieAeWyXU_keyframe.csv
# 获取keyframes，成功[0, 120, 308, 455, 878, 1282, 1389]
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# frame_number:0
# frame_number:120
# frame_number:308
# frame_number:455
# frame_number:878
# frame_number:1282
# frame_number:1389
# save_path/media/checkpoint/speech_data/抖音作品//ieA2m5p2/
# video_path/media/checkpoint/speech_data/抖音作品//ieA2m5p2//ieA2m5p2.mp4
# csv_path/media/checkpoint/speech_data/抖音作品//ieA2m5p2//str/ieA2m5p2.csv
# output_csv_path/media/checkpoint/speech_data/抖音作品//ieA2m5p2//str/ieA2m5p2_keyframe.csv
# 获取keyframes，成功[0, 84, 189, 314, 367, 482, 547, 617, 702, 752]
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# frame_number:0
# frame_number:84
# frame_number:189
# frame_number:314
# frame_number:367
# frame_number:482
# frame_number:547
# frame_number:617
# frame_number:702
# frame_number:752
# save_path/media/checkpoint/speech_data/抖音作品//ieA2E1F7/
# video_path/media/checkpoint/speech_data/抖音作品//ieA2E1F7//ieA2E1F7.mp4
# csv_path/media/checkpoint/speech_data/抖音作品//ieA2E1F7//str/ieA2E1F7.csv
# output_csv_path/media/checkpoint/speech_data/抖音作品//ieA2E1F7//str/ieA2E1F7_keyframe.csv
# 获取keyframes，成功[0, 183, 278, 309, 465, 611, 883, 1111, 1255, 1328, 1388, 1469, 1515, 1601, 1725, 1857, 2012]
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# frame_number:0
# frame_number:183
# frame_number:278
# frame_number:309
# frame_number:465
# frame_number:611
# frame_number:883
# frame_number:1111
# frame_number:1255
# frame_number:1328
# frame_number:1388
# frame_number:1469
# frame_number:1515
# frame_number:1601
# frame_number:1725
# frame_number:1857
# frame_number:2012
# save_path/media/checkpoint/speech_data/抖音作品//ieA2wWb3/
# video_path/media/checkpoint/speech_data/抖音作品//ieA2wWb3//ieA2wWb3.mp4
# csv_path/media/checkpoint/speech_data/抖音作品//ieA2wWb3//str/ieA2wWb3.csv
# output_csv_path/media/checkpoint/speech_data/抖音作品//ieA2wWb3//str/ieA2wWb3_keyframe.csv
# 获取keyframes，成功[0, 3, 81, 153, 332, 653, 739, 818]
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# frame_number:0
# frame_number:3
# frame_number:81
# frame_number:153
# frame_number:332
# frame_number:653
# frame_number:739
# frame_number:818
# save_path/media/checkpoint/speech_data/抖音作品//ieA2cW4T/
# video_path/media/checkpoint/speech_data/抖音作品//ieA2cW4T//ieA2cW4T.mp4
# csv_path/media/checkpoint/speech_data/抖音作品//ieA2cW4T//str/ieA2cW4T.csv
# output_csv_path/media/checkpoint/speech_data/抖音作品//ieA2cW4T//str/ieA2cW4T_keyframe.csv
# 获取keyframes，成功[0, 410, 646, 662, 677]
# frame_number:0
# frame_number:410
# frame_number:646
# frame_number:662
# frame_number:677
# frame_number:0
# frame_number:410
# frame_number:646
# frame_number:662
# frame_number:677
# frame_number:0
# frame_number:410
# frame_number:646
# frame_number:662
# frame_number:677
# save_path/media/checkpoint/speech_data/抖音作品//ieA2bFTe/
# video_path/media/checkpoint/speech_data/抖音作品//ieA2bFTe//ieA2bFTe.mp4
# csv_path/media/checkpoint/speech_data/抖音作品//ieA2bFTe//str/ieA2bFTe.csv
# output_csv_path/media/checkpoint/speech_data/抖音作品//ieA2bFTe//str/ieA2bFTe_keyframe.csv
# 获取keyframes，成功[0, 2, 157, 362, 586, 770, 1257]
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# frame_number:0
# frame_number:2
# frame_number:157
# frame_number:362
# frame_number:586
# frame_number:770
# frame_number:1257
# save_path/media/checkpoint/speech_data/抖音作品//ieAjabk1/
# video_path/media/checkpoint/speech_data/抖音作品//ieAjabk1//ieAjabk1.mp4
# csv_path/media/checkpoint/speech_data/抖音作品//ieAjabk1//str/ieAjabk1.csv
# output_csv_path/media/checkpoint/speech_data/抖音作品//ieAjabk1//str/ieAjabk1_keyframe.csv
# 获取keyframes，成功[0, 218, 333, 394, 604, 817, 932, 1207, 1249, 1343, 1492, 1767]
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# frame_number:0
# frame_number:218
# frame_number:333
# frame_number:394
# frame_number:604
# frame_number:817
# frame_number:932
# frame_number:1207
# frame_number:1249
# frame_number:1343
# frame_number:1492
# frame_number:1767
# save_path/media/checkpoint/speech_data/抖音作品//ieAjskDr/
# video_path/media/checkpoint/speech_data/抖音作品//ieAjskDr//ieAjskDr.mp4
# csv_path/media/checkpoint/speech_data/抖音作品//ieAjskDr//str/ieAjskDr.csv
# output_csv_path/media/checkpoint/speech_data/抖音作品//ieAjskDr//str/ieAjskDr_keyframe.csv
# 获取keyframes，成功[0, 679, 1261, 2106, 2504, 2578]
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# frame_number:0
# frame_number:679
# frame_number:1261
# frame_number:2106
# frame_number:2504
# frame_number:2578
# save_path/media/checkpoint/speech_data/抖音作品//ieA6rFPh/
# video_path/media/checkpoint/speech_data/抖音作品//ieA6rFPh//ieA6rFPh.mp4
# csv_path/media/checkpoint/speech_data/抖音作品//ieA6rFPh//str/ieA6rFPh.csv
# output_csv_path/media/checkpoint/speech_data/抖音作品//ieA6rFPh//str/ieA6rFPh_keyframe.csv
# 获取keyframes，成功[0, 105, 141, 153, 248, 296, 345, 456, 621, 942, 1046, 1133, 1180, 1241, 1305, 1381]
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# frame_number:0
# frame_number:105
# frame_number:141
# frame_number:153
# frame_number:248
# frame_number:296
# frame_number:345
# frame_number:456
# frame_number:621
# frame_number:942
# frame_number:1046
# frame_number:1133
# frame_number:1180
# frame_number:1241
# frame_number:1305
# frame_number:1381
# save_path/media/checkpoint/speech_data/抖音作品//ieAkpNXB/
# video_path/media/checkpoint/speech_data/抖音作品//ieAkpNXB//ieAkpNXB.mp4
# csv_path/media/checkpoint/speech_data/抖音作品//ieAkpNXB//str/ieAkpNXB.csv
# output_csv_path/media/checkpoint/speech_data/抖音作品//ieAkpNXB//str/ieAkpNXB_keyframe.csv
# 获取keyframes，成功[0, 123, 308, 387, 853, 988, 1210, 1240]
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# frame_number:0
# frame_number:123
# frame_number:308
# frame_number:387
# frame_number:853
# frame_number:988
# frame_number:1210
# frame_number:1240
# save_path/media/checkpoint/speech_data/抖音作品//ieDRHjmD/
# video_path/media/checkpoint/speech_data/抖音作品//ieDRHjmD//ieDRHjmD.mp4
# csv_path/media/checkpoint/speech_data/抖音作品//ieDRHjmD//str/ieDRHjmD.csv
# output_csv_path/media/checkpoint/speech_data/抖音作品//ieDRHjmD//str/ieDRHjmD_keyframe.csv
# 获取keyframes，成功[0]
# frame_number:0
# frame_number:0
# frame_number:0
